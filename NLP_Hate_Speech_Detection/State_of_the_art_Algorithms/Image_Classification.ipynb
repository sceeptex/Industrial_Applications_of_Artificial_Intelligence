# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Installation

# %%
import numpy as np
import os

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

# %%
folder_ST = 'drive/MyDrive/Industrial_Applications_of_AI/Tertiary_Sector/TransformSociety'

# %% [markdown]
# # Keras Application simple

# %%
model = ResNet50(weights='imagenet')

# %%
os.getcwd()
# Out:
# '/content'

# %%
img_path = 'Data/Elephant.jpg'
img = image.load_img(os.path.join(folder_ST,img_path), target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n0250401
# Out:
# Predicted: [('n02504458', 'African_elephant', 0.88681036), ('n01871265', 'tusker', 0.040444024), ('n02504013', 'Indian_elephant', 0.034975395)]

# %% [markdown]
# # Keras Application Best of class

# %%
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2M
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input, decode_predictions

# %%
model_BoC = EfficientNetV2M(weights='imagenet')

# %%
img_path = 'Data/Elephant.jpg'
img = image.load_img(os.path.join(folder_ST,img_path), target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=5)[0])
# Predicted: [(u'n0250401
# Out:
# Predicted: [('n02504458', 'African_elephant', 0.89992523), ('n01871265', 'tusker', 0.02612238), ('n02504013', 'Indian_elephant', 0.010501924), ('n04259630', 'sombrero', 0.0070466856), ('n03388043', 'fountain', 0.005747636)]

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds)[0])
# Predicted: [(u'n0250401
# Out:
# Predicted: [('n02504458', 'African_elephant', 0.89992523), ('n01871265', 'tusker', 0.02612238), ('n02504013', 'Indian_elephant', 0.010501924), ('n04259630', 'sombrero', 0.0070466856), ('n03388043', 'fountain', 0.005747636)]

# %% [markdown]
# # Detect military equipment in ukraine

# %%
img_dir_wuk = 'Data/wuk'
images_path = os.listdir(os.path.join(folder_ST,img_dir_wuk))

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
for image_path in images_path:
  print('\nImage:',os.path.join(folder_ST,img_dir_wuk,image_path))
  img = mpimg.imread(os.path.join(folder_ST,img_dir_wuk,image_path))
  imgplot = plt.imshow(img)
  plt.show()

  img = image.load_img(os.path.join(folder_ST,img_dir_wuk,image_path), target_size=(224, 224))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)

  preds = model.predict(x)
  print('Predicted:')#, decode_predictions(preds, top=10)[0])
  predictions = decode_predictions(preds, top=10)[0]


  dict_prediction_class_score = {}
  dict_prediction_class_abbreviation = {}
  for prediction in predictions:
    
    class_abbreviation, class_name, pred_score = prediction
    dict_prediction_class_score[str(class_name)] = pred_score
    dict_prediction_class_abbreviation[str(class_name)] = class_abbreviation
    print(pred_score,'\t',class_name )
  print(dict_prediction_class_score)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # use predictions

# %%
predictions = decode_predictions(preds, top=2000)[0]

# %%
predictions[0]
# Out:
# ('n02504458', 'African_elephant', 0.89992523)

# %%
dict_prediction_class_score = {}
dict_prediction_class_abbreviation = {}
for prediction in predictions:
  class_abbreviation, class_name, pred_score = prediction
  dict_prediction_class_score[str(class_name)] = pred_score
  dict_prediction_class_abbreviation[str(class_name)] = class_abbreviation

# %%
for i, key in enumerate(dict_prediction_class_score.keys()):
  print(i, key)
# Out:
# 0 African_elephant
# 1 tusker
# 2 Indian_elephant
# 3 sombrero
# 4 fountain
# 5 teddy
# 6 mushroom
# 7 standard_poodle
# 8 triceratops
# 9 megalith
# 10 ice_bear
# 11 shower_cap
# 12 toy_poodle
# 13 umbrella
# 14 Newfoundland
# 15 Kerry_blue_terrier
# 16 Bedlington_terrier
# 17 seashore
# 18 cocker_spaniel
# 19 chain_mail
# 20 radio_telescope
# 21 brass
# 22 Bouvier_des_Flandres
# 23 Afghan_hound
# 24 diaper
# 25 soft-coated_wheaten_terrier
# 26 pedestal
# 27 shovel
# 28 chow
# 29 promontory
# 30 Sealyham_terrier
# 31 bonnet
# 32 miniature_poodle
# 33 Irish_water_spaniel
# 34 web_site
# 35 pillow
# 36 Egyptian_cat
# 37 Airedale
# 38 table_lamp
# 39 French_bulldog
# 40 bow_tie
# 41 hatchet
# 42 Weimaraner
# 43 boxer
# 44 sandbar
# 45 parachute
# 46 komondor
# 47 cowboy_hat
# 48 sarong
# 49 Old_English_sheepdog
# 50 Lakeland_terrier
# 51 cowboy_boot
# 52 rifle
# 53 ram
# 54 electric_ray
# 55 gown
# 56 park_bench
# 57 car_mirror
# 58 hippopotamus
# 59 jean
# 60 cougar
# 61 quilt
# 62 bolo_tie
# 63 strainer
# 64 Gordon_setter
# 65 kuvasz
# 66 dugong
# 67 miniature_schnauzer
# 68 giant_schnauzer
# 69 safety_pin
# 70 nail
# 71 totem_pole
# 72 breastplate
# 73 sweatshirt
# 74 pug
# 75 cup
# 76 assault_rifle
# 77 lampshade
# 78 fur_coat
# 79 Samoyed
# 80 wreck
# 81 jellyfish
# 82 bucket
# 83 Pembroke
# 84 tiger_cat
# 85 cliff
# 86 jersey
# 87 zebra
# 88 brown_bear
# 89 rocking_chair
# 90 agaric
# 91 Great_Pyrenees
# 92 beagle
# 93 abaya
# 94 great_grey_owl
# 95 plastic_bag
# 96 shield
# 97 Maltese_dog
# 98 wool
# 99 bison
# 100 dalmatian
# 101 Bernese_mountain_dog
# 102 Sussex_spaniel
# 103 Chesapeake_Bay_retriever
# 104 golden_retriever
# 105 Mexican_hairless
# 106 knee_pad
# 107 sunglass
# 108 cardigan
# 109 pajama
# 110 stethoscope
# 111 gorilla
# 112 flat-coated_retriever
# 113 sock
# 114 golfcart
# 115 swimming_trunks
# 116 studio_couch
# 117 wire-haired_fox_terrier
# 118 curly-coated_retriever
# 119 hammer
# 120 cloak
# 121 coho
# 122 stole
# 123 swab
# 124 electric_fan
# 125 binoculars
# 126 West_Highland_white_terrier
# 127 tabby
# 128 military_uniform
# 129 clumber
# 130 window_shade
# 131 malamute
# 132 German_short-haired_pointer
# 133 feather_boa
# 134 earthstar
# 135 bassinet
# 136 cuirass
# 137 window_screen
# 138 basset
# 139 bell_cote
# 140 bolete
# 141 bluetick
# 142 Tibetan_terrier
# 143 bull_mastiff
# 144 digital_clock
# 145 vase
# 146 crutch
# 147 trombone
# 148 frilled_lizard
# 149 overskirt
# 150 pot
# 151 vault
# 152 wig
# 153 honeycomb
# 154 pitcher
# 155 wooden_spoon
# 156 tiger
# 157 hammerhead
# 158 Tibetan_mastiff
# 159 Cardigan
# 160 throne
# 161 screw
# 162 briard
# 163 trilobite
# 164 seat_belt
# 165 ski_mask
# 166 English_springer
# 167 Komodo_dragon
# 168 lumbermill
# 169 mortarboard
# 170 Brittany_spaniel
# 171 gong
# 172 tractor
# 173 ski
# 174 cannon
# 175 goblet
# 176 baboon
# 177 leatherback_turtle
# 178 muzzle
# 179 harp
# 180 Leonberg
# 181 paddle
# 182 dishrag
# 183 dumbbell
# 184 sleeping_bag
# 185 Boston_bull
# 186 groom
# 187 American_black_bear
# 188 sundial
# 189 toilet_seat
# 190 bearskin
# 191 cornet
# 192 kelpie
# 193 paintbrush
# 194 solar_dish
# 195 water_buffalo
# 196 amphibian
# 197 suit
# 198 vizsla
# 199 jigsaw_puzzle
# 200 hen-of-the-woods
# 201 weasel
# 202 affenpinscher
# 203 perfume
# 204 padlock
# 205 bathtub
# 206 armadillo
# 207 schipperke
# 208 matchstick
# 209 mask
# 210 conch
# 211 chimpanzee
# 212 dining_table
# 213 sewing_machine
# 214 buckle
# 215 cliff_dwelling
# 216 space_shuttle
# 217 Border_collie
# 218 chime
# 219 redbone
# 220 Scotch_terrier
# 221 maillot
# 222 standard_schnauzer
# 223 bikini
# 224 mosquito_net
# 225 Staffordshire_bullterrier
# 226 sunglasses
# 227 killer_whale
# 228 stretcher
# 229 patio
# 230 terrapin
# 231 candle
# 232 spotlight
# 233 EntleBucher
# 234 grey_whale
# 235 refrigerator
# 236 sturgeon
# 237 piggy_bank
# 238 Great_Dane
# 239 academic_gown
# 240 king_penguin
# 241 sax
# 242 pool_table
# 243 Arabian_camel
# 244 dough
# 245 violin
# 246 snowmobile
# 247 hamper
# 248 water_bottle
# 249 bathing_cap
# 250 warthog
# 251 hoopskirt
# 252 macaque
# 253 tripod
# 254 African_grey
# 255 jinrikisha
# 256 cash_machine
# 257 coral_fungus
# 258 Siberian_husky
# 259 marimba
# 260 cradle
# 261 abacus
# 262 iron
# 263 hyena
# 264 strawberry
# 265 plow
# 266 loupe
# 267 poncho
# 268 barrow
# 269 Saint_Bernard
# 270 kimono
# 271 drum
# 272 monastery
# 273 coral_reef
# 274 hook
# 275 macaw
# 276 bighorn
# 277 ice_lolly
# 278 Siamese_cat
# 279 bath_towel
# 280 tub
# 281 stage
# 282 Greater_Swiss_Mountain_dog
# 283 prayer_rug
# 284 trench_coat
# 285 screwdriver
# 286 desk
# 287 knot
# 288 skunk
# 289 Lhasa
# 290 bannister
# 291 miniskirt
# 292 crossword_puzzle
# 293 Irish_setter
# 294 pier
# 295 starfish
# 296 brain_coral
# 297 cellular_telephone
# 298 potter's_wheel
# 299 groenendael
# 300 miniature_pinscher
# 301 handkerchief
# 302 tray
# 303 Yorkshire_terrier
# 304 Rottweiler
# 305 Chihuahua
# 306 gas_pump
# 307 chain_saw
# 308 common_iguana
# 309 remote_control
# 310 grey_fox
# 311 French_horn
# 312 leopard
# 313 orange
# 314 Rhodesian_ridgeback
# 315 Scottish_deerhound
# 316 saltshaker
# 317 black-and-tan_coonhound
# 318 recreational_vehicle
# 319 loggerhead
# 320 maraca
# 321 caldron
# 322 puck
# 323 geyser
# 324 cicada
# 325 banjo
# 326 coyote
# 327 Christmas_stocking
# 328 Labrador_retriever
# 329 torch
# 330 washbasin
# 331 picket_fence
# 332 great_white_shark
# 333 Irish_terrier
# 334 dragonfly
# 335 Blenheim_spaniel
# 336 hog
# 337 street_sign
# 338 sliding_door
# 339 sea_urchin
# 340 badger
# 341 football_helmet
# 342 pirate
# 343 snow_leopard
# 344 airship
# 345 car_wheel
# 346 velvet
# 347 cello
# 348 thatch
# 349 bubble
# 350 bloodhound
# 351 panpipe
# 352 broom
# 353 corkscrew
# 354 canoe
# 355 papillon
# 356 loudspeaker
# 357 plunger
# 358 can_opener
# 359 box_turtle
# 360 Shih-Tzu
# 361 collie
# 362 cairn
# 363 ashcan
# 364 Dandie_Dinmont
# 365 shoji
# 366 chain
# 367 Australian_terrier
# 368 turnstile
# 369 microphone
# 370 lakeside
# 371 whistle
# 372 projector
# 373 drumstick
# 374 bassoon
# 375 vulture
# 376 sunscreen
# 377 triumphal_arch
# 378 projectile
# 379 tricycle
# 380 lighter
# 381 llama
# 382 American_Staffordshire_terrier
# 383 pick
# 384 spatula
# 385 forklift
# 386 Persian_cat
# 387 cheetah
# 388 gyromitra
# 389 Border_terrier
# 390 ringlet
# 391 German_shepherd
# 392 Arctic_fox
# 393 necklace
# 394 hourglass
# 395 soccer_ball
# 396 screen
# 397 rule
# 398 container_ship
# 399 wine_bottle
# 400 holster
# 401 Welsh_springer_spaniel
# 402 keeshond
# 403 Brabancon_griffon
# 404 American_alligator
# 405 silky_terrier
# 406 hand_blower
# 407 snorkel
# 408 lab_coat
# 409 birdhouse
# 410 bib
# 411 face_powder
# 412 unicycle
# 413 sandal
# 414 chambered_nautilus
# 415 barometer
# 416 mitten
# 417 clog
# 418 dishwasher
# 419 beaker
# 420 prison
# 421 motor_scooter
# 422 hair_slide
# 423 banana
# 424 gasmask
# 425 Doberman
# 426 flute
# 427 paddlewheel
# 428 Norwich_terrier
# 429 shower_curtain
# 430 guacamole
# 431 barrel
# 432 Band_Aid
# 433 Shetland_sheepdog
# 434 Norwegian_elkhound
# 435 stone_wall
# 436 snowplow
# 437 volcano
# 438 scale
# 439 neck_brace
# 440 cab
# 441 mailbox
# 442 grand_piano
# 443 Norfolk_terrier
# 444 drilling_platform
# 445 sloth_bear
# 446 barber_chair
# 447 flagpole
# 448 letter_opener
# 449 envelope
# 450 photocopier
# 451 water_jug
# 452 fly
# 453 coffee_mug
# 454 red_wine
# 455 ocarina
# 456 Appenzeller
# 457 lynx
# 458 jeep
# 459 American_coot
# 460 maze
# 461 stinkhorn
# 462 pickelhaube
# 463 thimble
# 464 hermit_crab
# 465 bicycle-built-for-two
# 466 Pomeranian
# 467 obelisk
# 468 doormat
# 469 packet
# 470 guinea_pig
# 471 radiator
# 472 accordion
# 473 half_track
# 474 wild_boar
# 475 bow
# 476 computer_keyboard
# 477 dogsled
# 478 hay
# 479 carousel
# 480 tile_roof
# 481 bookshop
# 482 missile
# 483 crib
# 484 mailbag
# 485 rubber_eraser
# 486 cleaver
# 487 ruffed_grouse
# 488 Irish_wolfhound
# 489 minibus
# 490 carton
# 491 broccoli
# 492 white_wolf
# 493 plate
# 494 Pekinese
# 495 tank
# 496 lion
# 497 lens_cap
# 498 altar
# 499 ox
# 500 orangutan
# 501 balloon
# 502 oxygen_mask
# 503 lotion
# 504 Angora
# 505 wombat
# 506 lawn_mower
# 507 ping-pong_ball
# 508 comic_book
# 509 catamaran
# 510 alp
# 511 oboe
# 512 pinwheel
# 513 radio
# 514 mountain_bike
# 515 harmonica
# 516 running_shoe
# 517 lycaenid
# 518 lemon
# 519 palace
# 520 notebook
# 521 castle
# 522 spindle
# 523 black_swan
# 524 pineapple
# 525 English_setter
# 526 diamondback
# 527 rain_barrel
# 528 mountain_tent
# 529 acorn
# 530 power_drill
# 531 beer_glass
# 532 jackfruit
# 533 steel_drum
# 534 eft
# 535 scabbard
# 536 plate_rack
# 537 cocktail_shaker
# 538 spoonbill
# 539 goose
# 540 dung_beetle
# 541 colobus
# 542 limousine
# 543 lionfish
# 544 mortar
# 545 paper_towel
# 546 beer_bottle
# 547 zucchini
# 548 monitor
# 549 otterhound
# 550 sea_snake
# 551 snail
# 552 iPod
# 553 jay
# 554 basenji
# 555 convertible
# 556 stupa
# 557 tennis_ball
# 558 laptop
# 559 goldfish
# 560 gibbon
# 561 swing
# 562 toyshop
# 563 shopping_cart
# 564 minivan
# 565 vestment
# 566 hair_spray
# 567 anemone_fish
# 568 Gila_monster
# 569 book_jacket
# 570 ballpoint
# 571 cauliflower
# 572 titi
# 573 sea_anemone
# 574 coffeepot
# 575 nipple
# 576 otter
# 577 stove
# 578 lacewing
# 579 grille
# 580 rock_beauty
# 581 oil_filter
# 582 schooner
# 583 hamster
# 584 admiral
# 585 burrito
# 586 koala
# 587 safe
# 588 croquet_ball
# 589 platypus
# 590 folding_chair
# 591 crane
# 592 frying_pan
# 593 breakwater
# 594 Windsor_tie
# 595 dome
# 596 menu
# 597 file
# 598 valley
# 599 chest
# 600 spider_web
# 601 television
# 602 chainlink_fence
# 603 American_chameleon
# 604 disk_brake
# 605 carpenter's_kit
# 606 bulletproof_vest
# 607 bobsled
# 608 mixing_bowl
# 609 bookcase
# 610 English_foxhound
# 611 shopping_basket
# 612 analog_clock
# 613 Walker_hound
# 614 walking_stick
# 615 pomegranate
# 616 ballplayer
# 617 tench
# 618 Ibizan_hound
# 619 joystick
# 620 bee
# 621 microwave
# 622 wood_rabbit
# 623 Polaroid_camera
# 624 dial_telephone
# 625 aircraft_carrier
# 626 upright
# 627 wall_clock
# 628 wok
# 629 Granny_Smith
# 630 porcupine
# 631 damselfly
# 632 parking_meter
# 633 printer
# 634 Madagascar_cat
# 635 rock_crab
# 636 tiger_shark
# 637 washer
# 638 hip
# 639 Italian_greyhound
# 640 rotisserie
# 641 quail
# 642 ostrich
# 643 crash_helmet
# 644 four-poster
# 645 fire_screen
# 646 ambulance
# 647 Loafer
# 648 plane
# 649 puffer
# 650 malinois
# 651 stingray
# 652 acoustic_guitar
# 653 scuba_diver
# 654 punching_bag
# 655 brassiere
# 656 gar
# 657 ladle
# 658 isopod
# 659 china_cabinet
# 660 barn
# 661 nematode
# 662 yurt
# 663 jaguar
# 664 magpie
# 665 fig
# 666 red_wolf
# 667 revolver
# 668 balance_beam
# 669 sulphur-crested_cockatoo
# 670 Eskimo_dog
# 671 meerkat
# 672 giant_panda
# 673 whiskey_jug
# 674 restaurant
# 675 warplane
# 676 electric_guitar
# 677 horse_cart
# 678 redshank
# 679 sea_cucumber
# 680 mud_turtle
# 681 mink
# 682 waffle_iron
# 683 three-toed_sloth
# 684 mantis
# 685 pelican
# 686 theater_curtain
# 687 African_hunting_dog
# 688 bald_eagle
# 689 pickup
# 690 vacuum
# 691 steam_locomotive
# 692 speedboat
# 693 maypole
# 694 pencil_sharpener
# 695 dock
# 696 proboscis_monkey
# 697 school_bus
# 698 capuchin
# 699 cucumber
# 700 beaver
# 701 ear
# 702 spiny_lobster
# 703 polecat
# 704 rapeseed
# 705 daisy
# 706 Saluki
# 707 lipstick
# 708 crate
# 709 planetarium
# 710 scoreboard
# 711 parallel_bars
# 712 black_grouse
# 713 racket
# 714 sorrel
# 715 tow_truck
# 716 freight_car
# 717 Petri_dish
# 718 entertainment_center
# 719 peacock
# 720 alligator_lizard
# 721 cabbage_butterfly
# 722 dingo
# 723 ice_cream
# 724 red_fox
# 725 golf_ball
# 726 manhole_cover
# 727 wardrobe
# 728 corn
# 729 indri
# 730 reel
# 731 banded_gecko
# 732 eel
# 733 African_chameleon
# 734 water_ouzel
# 735 ladybug
# 736 submarine
# 737 boa_constrictor
# 738 Japanese_spaniel
# 739 whippet
# 740 oxcart
# 741 house_finch
# 742 eggnog
# 743 magnetic_compass
# 744 slot
# 745 cockroach
# 746 church
# 747 toilet_tissue
# 748 soap_dispenser
# 749 soup_bowl
# 750 pay-phone
# 751 viaduct
# 752 beach_wagon
# 753 chocolate_sauce
# 754 rugby_ball
# 755 switch
# 756 odometer
# 757 patas
# 758 measuring_cup
# 759 African_crocodile
# 760 lesser_panda
# 761 butternut_squash
# 762 agama
# 763 home_theater
# 764 trifle
# 765 borzoi
# 766 pill_bottle
# 767 wing
# 768 squirrel_monkey
# 769 dam
# 770 black-footed_ferret
# 771 tick
# 772 centipede
# 773 meat_loaf
# 774 cinema
# 775 quill
# 776 wallet
# 777 tree_frog
# 778 milk_can
# 779 chiffonier
# 780 vending_machine
# 781 toaster
# 782 apron
# 783 jack-o'-lantern
# 784 teapot
# 785 trimaran
# 786 kit_fox
# 787 mobile_home
# 788 backpack
# 789 echidna
# 790 European_fire_salamander
# 791 moped
# 792 albatross
# 793 ant
# 794 American_lobster
# 795 barracouta
# 796 racer
# 797 partridge
# 798 crayfish
# 799 cassette_player
# 800 head_cabbage
# 801 pop_bottle
# 802 fox_squirrel
# 803 basketball
# 804 mousetrap
# 805 baseball
# 806 flatworm
# 807 robin
# 808 slide_rule
# 809 bottlecap
# 810 rock_python
# 811 rhinoceros_beetle
# 812 potpie
# 813 desktop_computer
# 814 Crock_Pot
# 815 lifeboat
# 816 liner
# 817 scorpion
# 818 pencil_box
# 819 American_egret
# 820 red-breasted_merganser
# 821 slug
# 822 pole
# 823 sea_lion
# 824 pretzel
# 825 steel_arch_bridge
# 826 shoe_shop
# 827 library
# 828 espresso
# 829 green_lizard
# 830 indigo_bunting
# 831 bell_pepper
# 832 guillotine
# 833 chickadee
# 834 junco
# 835 prairie_chicken
# 836 barbell
# 837 siamang
# 838 hen
# 839 marmot
# 840 toy_terrier
# 841 stopwatch
# 842 worm_fence
# 843 Dutch_oven
# 844 mosque
# 845 espresso_maker
# 846 Dungeness_crab
# 847 mongoose
# 848 syringe
# 849 bullfrog
# 850 coil
# 851 beacon
# 852 binder
# 853 custard_apple
# 854 bulbul
# 855 mashed_potato
# 856 thresher
# 857 little_blue_heron
# 858 fire_engine
# 859 medicine_chest
# 860 space_heater
# 861 ringneck_snake
# 862 langur
# 863 boathouse
# 864 harvester
# 865 timber_wolf
# 866 bagel
# 867 hare
# 868 Model_T
# 869 tape_player
# 870 sea_slug
# 871 mouse
# 872 king_snake
# 873 reflex_camera
# 874 vine_snake
# 875 hotdog
# 876 cock
# 877 hornbill
# 878 dowitcher
# 879 police_van
# 880 oystercatcher
# 881 grocery_store
# 882 combination_lock
# 883 green_mamba
# 884 suspension_bridge
# 885 artichoke
# 886 black_and_gold_garden_spider
# 887 long-horned_beetle
# 888 French_loaf
# 889 marmoset
# 890 common_newt
# 891 spotted_salamander
# 892 typewriter_keyboard
# 893 whiptail
# 894 howler_monkey
# 895 monarch
# 896 yawl
# 897 fountain_pen
# 898 consomme
# 899 bakery
# 900 chiton
# 901 cardoon
# 902 butcher_shop
# 903 leafhopper
# 904 trailer_truck
# 905 carbonara
# 906 bullet_train
# 907 toucan
# 908 water_tower
# 909 wolf_spider
# 910 impala
# 911 ground_beetle
# 912 sidewinder
# 913 lorikeet
# 914 tailed_frog
# 915 cassette
# 916 hummingbird
# 917 hognose_snake
# 918 spider_monkey
# 919 go-kart
# 920 European_gallinule
# 921 thunder_snake
# 922 white_stork
# 923 ptarmigan
# 924 ruddy_turnstone
# 925 flamingo
# 926 spaghetti_squash
# 927 gondola
# 928 kite
# 929 greenhouse
# 930 pizza
# 931 electric_locomotive
# 932 horizontal_bar
# 933 wallaby
# 934 purse
# 935 space_bar
# 936 CD_player
# 937 green_snake
# 938 tobacco_shop
# 939 modem
# 940 streetcar
# 941 guenon
# 942 hartebeest
# 943 airliner
# 944 tarantula
# 945 horned_viper
# 946 water_snake
# 947 drake
# 948 garden_spider
# 949 night_snake
# 950 moving_van
# 951 ibex
# 952 digital_watch
# 953 buckeye
# 954 passenger_car
# 955 fireboat
# 956 limpkin
# 957 fiddler_crab
# 958 Indian_cobra
# 959 black_stork
# 960 harvestman
# 961 acorn_squash
# 962 traffic_light
# 963 cheeseburger
# 964 tiger_beetle
# 965 bustard
# 966 bee_eater
# 967 axolotl
# 968 gazelle
# 969 hard_disc
# 970 weevil
# 971 confectionery
# 972 garbage_truck
# 973 barbershop
# 974 barn_spider
# 975 apiary
# 976 red-backed_sandpiper
# 977 hand-held_computer
# 978 garter_snake
# 979 grasshopper
# 980 king_crab
# 981 sulphur_butterfly
# 982 hot_pot
# 983 leaf_beetle
# 984 coucal
# 985 cricket
# 986 organ
# 987 volleyball
# 988 oscilloscope
# 989 black_widow
# 990 sports_car
# 991 yellow_lady's_slipper
# 992 dhole
# 993 goldfinch
# 994 bittern
# 995 brambling
# 996 jacamar
# 997 trolleybus
